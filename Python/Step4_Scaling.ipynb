# %%
#  Imports

import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(os.path.join('..', 'Resources', 'Created_Files', 'Resampled_df.csv'))
df
# Out:
#         Gender  Age  Region_Code  Previously_Insured  Vehicle_Age  \
# 0            1   26         28.0                   1            1
# 1            1   37         46.0                   0            0
# 2            1   25         29.0                   1            1
# 3            0   25         35.0                   1            1
# 4            1   31          3.0                   0            1
# ...        ...  ...          ...                 ...          ...
# 500435       1   38         15.0                   0            0
# 500436       1   49         28.0                   0            0
# 500437       1   66         50.0                   0            2
# 500438       1   45         28.0                   0            0
# 500439       0   47         28.0                   0            0
#
#         Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0                    0        125876.0                 152.0       37
# 1                    1         33097.0                  26.0       38
# 2                    0         32113.0                 152.0      293
# 3                    0         26299.0                 152.0       30
# 4                    1         22523.0                 163.0       71
# ...                ...             ...                   ...      ...
# 500435               1         38086.0                 124.0      134
# 500436               1         28099.0                 124.0       85
# 500437               1         46261.0                   8.0      298
# 500438               1         38876.0                 124.0      208
# 500439               1         30564.0                  26.0      114
#
#         Response
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1
# ...          ...
# 500435         1
# 500436         1
# 500437         1
# 500438         1
# 500439         1
#
# [500440 rows x 10 columns]
